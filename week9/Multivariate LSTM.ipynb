# %% [markdown]
# Adopted from https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/

# %% [markdown]
# # Prepare the data

# %% [markdown]
# 1. No: row number
# 2. year: year of data in this row
# 3. month: month of data in this row
# 4. day: day of data in this row
# 5. hour: hour of data in this row
# 6. pm2.5: PM2.5 concentration
# 7. DEWP: Dew Point
# 8. TEMP: Temperature
# 9. PRES: Pressure
# 10. cbwd: Combined wind direction
# 11. Iws: Cumulated wind speed
# 12. Is: Cumulated hours of snow
# 13. Ir: Cumulated hours of rain

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# load data
def parse(x):
    return datetime.strptime(x, '%Y %m %d %H')

# %%
dataset = pd.read_csv('raw.csv',  parse_dates = [['year', 'month', 'day', 'hour']], index_col=0, date_parser=parse)
dataset.head()
# Out:
#                      No  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# year_month_day_hour
# 2010-01-01 00:00:00   1    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 2010-01-01 01:00:00   2    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2010-01-01 02:00:00   3    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 2010-01-01 03:00:00   4    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 2010-01-01 04:00:00   5    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %%
dataset.drop('No', axis=1, inplace=True)

# manually specify column names
dataset.columns = ['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']
dataset.index.name = 'date'

# mark all NA values with 0
dataset['pollution'].fillna(0, inplace=True)

# drop the first 24 hours
dataset = dataset[24:]
# summarize first 5 rows
print(dataset.head(5))
# Out:
#                      pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# date
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0      SE     1.79     0     0
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0      SE     2.68     0     0
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0      SE     3.57     0     0
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0      SE     5.36     1     0
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0      SE     6.25     2     0

# %%
# save to file
dataset.to_csv('pollution.csv')

# %% [markdown]
# # Lets plot the data

# %%
from pandas import read_csv
from matplotlib import pyplot
# load dataset
dataset = pd.read_csv('pollution.csv', header=0, index_col=0)
values = dataset.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7]
i = 1
# plot each column
pyplot.figure()
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[:, group])
    pyplot.title(dataset.columns[group], y=0.5, loc='right')
    i += 1
pyplot.show()

# %% [markdown]
# # LSTM Data Preparation

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# get dataset values
dataset = read_csv('pollution.csv', header=0, index_col=0)
values = dataset.values

print(values.shape)

# integer encode direction
encoder = LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4])

# ensure all data is float
values = values.astype('float32')

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)

# drop columns we don't want to predict
reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed.head())
# Out:
# (43800, 8)
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.129779   0.352941   0.245902   0.527273   0.666667   0.002290
# 2   0.148893   0.367647   0.245902   0.527273   0.666667   0.003811
# 3   0.159960   0.426471   0.229508   0.545454   0.666667   0.005332
# 4   0.182093   0.485294   0.229508   0.563637   0.666667   0.008391
# 5   0.138833   0.485294   0.229508   0.563637   0.666667   0.009912
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1   0.000000        0.0  0.148893
# 2   0.000000        0.0  0.159960
# 3   0.000000        0.0  0.182093
# 4   0.037037        0.0  0.138833
# 5   0.074074        0.0  0.109658

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 365 * 24
#train = values[:n_train_hours, :]
#test = values[n_train_hours:, :]
train = values[:-n_train_hours, :]
test = values[-n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
print(train_X.shape[1], train_X.shape[2])
# Out:
# ((35039, 1, 8), (35039,), (8760, 1, 8), (8760,))
# (1, 8)

# %%
# design network
model = Sequential()
model.add(LSTM(36, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=144, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 35039 samples, validate on 8760 samples
# Epoch 1/144
# 3s - loss: 0.0358 - val_loss: 0.0478
# Epoch 2/144
# 3s - loss: 0.0151 - val_loss: 0.0204
# Epoch 3/144
# 3s - loss: 0.0141 - val_loss: 0.0148
# Epoch 4/144
# 2s - loss: 0.0140 - val_loss: 0.0133
# Epoch 5/144
# 2s - loss: 0.0139 - val_loss: 0.0131
# Epoch 6/144
# 2s - loss: 0.0139 - val_loss: 0.0131
# Epoch 7/144
# 2s - loss: 0.0139 - val_loss: 0.0131
# Epoch 8/144
# 2s - loss: 0.0138 - val_loss: 0.0131
# Epoch 9/144
# 2s - loss: 0.0139 - val_loss: 0.0131
# Epoch 10/144
# 2s - loss: 0.0138 - val_loss: 0.0133
# Epoch 11/144
# 2s - loss: 0.0138 - val_loss: 0.0133
# Epoch 12/144
# 2s - loss: 0.0138 - val_loss: 0.0134
# Epoch 13/144
# 2s - loss: 0.0138 - val_loss: 0.0133
# Epoch 14/144
# 2s - loss: 0.0138 - val_loss: 0.0135
# Epoch 15/144
# 2s - loss: 0.0138 - val_loss: 0.0133
# Epoch 16/144
# 2s - loss: 0.0138 - val_loss: 0.0133
# Epoch 17/144
# 2s - loss: 0.0137 - val_loss: 0.0136
# Epoch 18/144
# 2s - loss: 0.0137 - val_loss: 0.0133
# Epoch 19/144
# 2s - loss: 0.0138 - val_loss: 0.0136
# Epoch 20/144
# 2s - loss: 0.0138 - val_loss: 0.0135
# Epoch 21/144
# 2s - loss: 0.0137 - val_loss: 0.0136
# Epoch 22/144
# 2s - loss: 0.0138 - val_loss: 0.0134
# Epoch 23/144
# 2s - loss: 0.0137 - val_loss: 0.0134
# Epoch 24/144
# 2s - loss: 0.0137 - val_loss: 0.0135
# Epoch 25/144
# 2s - loss: 0.0137 - val_loss: 0.0135
# Epoch 26/144
# 2s - loss: 0.0137 - val_loss: 0.0136
# Epoch 27/144
# 2s - loss: 0.0137 - val_loss: 0.0140
# Epoch 28/144
# 2s - loss: 0.0137 - val_loss: 0.0138
# Epoch 29/144
# 2s - loss: 0.0137 - val_loss: 0.0138
# Epoch 30/144
# 2s - loss: 0.0137 - val_loss: 0.0139
# Epoch 31/144
# 3s - loss: 0.0137 - val_loss: 0.0138
# Epoch 32/144
# 2s - loss: 0.0137 - val_loss: 0.0138
# Epoch 33/144
# 2s - loss: 0.0137 - val_loss: 0.0138
# Epoch 34/144
# 3s - loss: 0.0137 - val_loss: 0.0140
# Epoch 35/144
# 2s - loss: 0.0137 - val_loss: 0.0138
# Epoch 36/144
# 3s - loss: 0.0137 - val_loss: 0.0136
# Epoch 37/144
# 2s - loss: 0.0137 - val_loss: 0.0136
# Epoch 38/144
# 3s - loss: 0.0137 - val_loss: 0.0136
# Epoch 39/144
# 3s - loss: 0.0137 - val_loss: 0.0136
# Epoch 40/144
# 2s - loss: 0.0136 - val_loss: 0.0135
# Epoch 41/144
# 2s - loss: 0.0137 - val_loss: 0.0136
# Epoch 42/144
# 2s - loss: 0.0137 - val_loss: 0.0133
# Epoch 43/144
# 3s - loss: 0.0136 - val_loss: 0.0134
# Epoch 44/144
# 4s - loss: 0.0136 - val_loss: 0.0134
# Epoch 45/144
# 3s - loss: 0.0136 - val_loss: 0.0133
# Epoch 46/144
# 2s - loss: 0.0136 - val_loss: 0.0136
# Epoch 47/144
# 3s - loss: 0.0136 - val_loss: 0.0133
# Epoch 48/144
# 2s - loss: 0.0136 - val_loss: 0.0134
# Epoch 49/144
# 3s - loss: 0.0136 - val_loss: 0.0133
# Epoch 50/144
# 3s - loss: 0.0136 - val_loss: 0.0133
# Epoch 51/144
# 3s - loss: 0.0136 - val_loss: 0.0133
# Epoch 52/144
# 3s - loss: 0.0136 - val_loss: 0.0133
# Epoch 53/144
# 2s - loss: 0.0136 - val_loss: 0.0132
# Epoch 54/144
# 3s - loss: 0.0136 - val_loss: 0.0132
# Epoch 55/144
# 3s - loss: 0.0136 - val_loss: 0.0132
# Epoch 56/144
# 3s - loss: 0.0136 - val_loss: 0.0132
# Epoch 57/144
# 3s - loss: 0.0136 - val_loss: 0.0135
# Epoch 58/144
# 2s - loss: 0.0135 - val_loss: 0.0131
# Epoch 59/144
# 3s - loss: 0.0135 - val_loss: 0.0132
# Epoch 60/144
# 2s - loss: 0.0136 - val_loss: 0.0133
# Epoch 61/144
# 3s - loss: 0.0135 - val_loss: 0.0132
# Epoch 62/144
# 3s - loss: 0.0135 - val_loss: 0.0130
# Epoch 63/144
# 3s - loss: 0.0135 - val_loss: 0.0132
# Epoch 64/144
# 3s - loss: 0.0135 - val_loss: 0.0134
# Epoch 65/144
# 2s - loss: 0.0135 - val_loss: 0.0133
# Epoch 66/144
# 3s - loss: 0.0135 - val_loss: 0.0135
# Epoch 67/144
# 3s - loss: 0.0135 - val_loss: 0.0132
# Epoch 68/144
# 3s - loss: 0.0135 - val_loss: 0.0132
# Epoch 69/144
# 3s - loss: 0.0135 - val_loss: 0.0134
# Epoch 70/144
# 2s - loss: 0.0135 - val_loss: 0.0135
# Epoch 71/144
# 2s - loss: 0.0135 - val_loss: 0.0134
# Epoch 72/144
# 2s - loss: 0.0135 - val_loss: 0.0133
# Epoch 73/144
# 3s - loss: 0.0135 - val_loss: 0.0131
# Epoch 74/144
# 4s - loss: 0.0135 - val_loss: 0.0133
# Epoch 75/144
# 3s - loss: 0.0135 - val_loss: 0.0134
# Epoch 76/144
# 2s - loss: 0.0135 - val_loss: 0.0134
# Epoch 77/144
# 3s - loss: 0.0135 - val_loss: 0.0136
# Epoch 78/144
# 3s - loss: 0.0135 - val_loss: 0.0134
# Epoch 79/144
# 3s - loss: 0.0135 - val_loss: 0.0134
# Epoch 80/144
# 3s - loss: 0.0135 - val_loss: 0.0134
# Epoch 81/144
# 3s - loss: 0.0135 - val_loss: 0.0133
# Epoch 82/144
# 3s - loss: 0.0135 - val_loss: 0.0135
# Epoch 83/144
# 3s - loss: 0.0135 - val_loss: 0.0133
# Epoch 84/144
# 3s - loss: 0.0135 - val_loss: 0.0134
# Epoch 85/144
# 3s - loss: 0.0135 - val_loss: 0.0133
# Epoch 86/144
# 3s - loss: 0.0135 - val_loss: 0.0137
# Epoch 87/144
# 3s - loss: 0.0135 - val_loss: 0.0136
# Epoch 88/144
# 2s - loss: 0.0135 - val_loss: 0.0135
# Epoch 89/144
# 3s - loss: 0.0135 - val_loss: 0.0135
# Epoch 90/144
# 2s - loss: 0.0135 - val_loss: 0.0138
# Epoch 91/144
# 3s - loss: 0.0135 - val_loss: 0.0136
# Epoch 92/144
# 3s - loss: 0.0135 - val_loss: 0.0138
# Epoch 93/144
# 3s - loss: 0.0134 - val_loss: 0.0135
# Epoch 94/144
# 3s - loss: 0.0135 - val_loss: 0.0137
# Epoch 95/144
# 2s - loss: 0.0135 - val_loss: 0.0137
# Epoch 96/144
# 3s - loss: 0.0135 - val_loss: 0.0135
# Epoch 97/144
# 3s - loss: 0.0135 - val_loss: 0.0135
# Epoch 98/144
# 3s - loss: 0.0135 - val_loss: 0.0136
# Epoch 99/144
# 3s - loss: 0.0134 - val_loss: 0.0137
# Epoch 100/144
# 3s - loss: 0.0134 - val_loss: 0.0136
# Epoch 101/144
# 3s - loss: 0.0134 - val_loss: 0.0136
# Epoch 102/144
# 2s - loss: 0.0134 - val_loss: 0.0135
# Epoch 103/144
# 3s - loss: 0.0134 - val_loss: 0.0137
# Epoch 104/144
# 3s - loss: 0.0134 - val_loss: 0.0135
# Epoch 105/144
# 3s - loss: 0.0134 - val_loss: 0.0137
# Epoch 106/144
# 3s - loss: 0.0134 - val_loss: 0.0135
# Epoch 107/144
# 2s - loss: 0.0135 - val_loss: 0.0135
# Epoch 108/144
# 3s - loss: 0.0134 - val_loss: 0.0137
# Epoch 109/144
# 2s - loss: 0.0134 - val_loss: 0.0137
# Epoch 110/144
# 3s - loss: 0.0134 - val_loss: 0.0138
# Epoch 111/144
# 3s - loss: 0.0134 - val_loss: 0.0137
# Epoch 112/144
# 2s - loss: 0.0134 - val_loss: 0.0137
# Epoch 113/144
# 3s - loss: 0.0134 - val_loss: 0.0136
# Epoch 114/144
# 2s - loss: 0.0134 - val_loss: 0.0138
# Epoch 115/144
# 3s - loss: 0.0134 - val_loss: 0.0138
# Epoch 116/144
# 3s - loss: 0.0134 - val_loss: 0.0138
# Epoch 117/144
# 3s - loss: 0.0134 - val_loss: 0.0137
# Epoch 118/144
# 3s - loss: 0.0134 - val_loss: 0.0137
# Epoch 119/144
# 2s - loss: 0.0134 - val_loss: 0.0137
# Epoch 120/144
# 3s - loss: 0.0134 - val_loss: 0.0138
# Epoch 121/144
# 4s - loss: 0.0134 - val_loss: 0.0139
# Epoch 122/144
# 4s - loss: 0.0134 - val_loss: 0.0138
# Epoch 123/144
# 3s - loss: 0.0134 - val_loss: 0.0136
# Epoch 124/144
# 2s - loss: 0.0134 - val_loss: 0.0136
# Epoch 125/144
# 3s - loss: 0.0134 - val_loss: 0.0138
# Epoch 126/144
# 3s - loss: 0.0134 - val_loss: 0.0139
# Epoch 127/144
# 3s - loss: 0.0134 - val_loss: 0.0139
# Epoch 128/144
# 3s - loss: 0.0134 - val_loss: 0.0139
# Epoch 129/144
# 2s - loss: 0.0134 - val_loss: 0.0138
# Epoch 130/144
# 3s - loss: 0.0134 - val_loss: 0.0140
# Epoch 131/144
# 2s - loss: 0.0134 - val_loss: 0.0138
# Epoch 132/144
# 3s - loss: 0.0134 - val_loss: 0.0135
# Epoch 133/144
# 3s - loss: 0.0134 - val_loss: 0.0137
# Epoch 134/144
# 3s - loss: 0.0134 - val_loss: 0.0138
# Epoch 135/144
# 4s - loss: 0.0134 - val_loss: 0.0138
# Epoch 136/144
# 4s - loss: 0.0134 - val_loss: 0.0141
# Epoch 137/144
# 4s - loss: 0.0134 - val_loss: 0.0139
# Epoch 138/144
# 3s - loss: 0.0134 - val_loss: 0.0137
# Epoch 139/144
# 2s - loss: 0.0134 - val_loss: 0.0139
# Epoch 140/144
# 3s - loss: 0.0134 - val_loss: 0.0137
# Epoch 141/144
# 3s - loss: 0.0134 - val_loss: 0.0138
# Epoch 142/144
# 3s - loss: 0.0134 - val_loss: 0.0138
# Epoch 143/144
# 3s - loss: 0.0134 - val_loss: 0.0139
# Epoch 144/144
# 3s - loss: 0.0134 - val_loss: 0.0142

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 25.582

# %% [markdown]
# # Next Challenge
# 1. tune this
# 2. https://www.kaggle.com/mczielinski/bitcoin-historical-data
